# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("spectrum.out", skiprows = 3)

# %%
lam_vals = data[:,0]
flux_vals = data[:,1]

# %%
plt.plot(lam_vals, flux_vals)
plt.xlim(4.69105, 4.69145)
plt.xlabel("Wavelength (microns)")
plt.ylabel("Intensity "+r'(ergs/s/cm$^2$/Hz/ster)')
plt.show()

# %%
np.linspace(4.69105, 4.69145, 10)
# Out:
# array([4.69105   , 4.69109444, 4.69113889, 4.69118333, 4.69122778,
#        4.69127222, 4.69131667, 4.69136111, 4.69140556, 4.69145   ])
