# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("spectrum.out", skiprows = 3)

# %%
data
# Out:
# array([[4.69093931e+00, 3.29624379e-20],
#        [4.69094563e+00, 3.29623626e-20],
#        [4.69095195e+00, 3.29622872e-20],
#        [4.69095827e+00, 3.29622119e-20],
#        [4.69096459e+00, 3.29621366e-20],
#        [4.69097092e+00, 3.29620613e-20],
#        [4.69097724e+00, 3.29619860e-20],
#        [4.69098356e+00, 3.29619107e-20],
#        [4.69098988e+00, 3.29618354e-20],
#        [4.69099620e+00, 3.29617601e-20],
#        [4.69100253e+00, 3.29616848e-20],
#        [4.69100885e+00, 3.29616095e-20],
#        [4.69101517e+00, 3.29615342e-20],
#        [4.69102149e+00, 3.29614589e-20],
#        [4.69102781e+00, 3.29613837e-20],
#        [4.69103414e+00, 3.29613086e-20],
#        [4.69104046e+00, 3.29612336e-20],
#        [4.69104678e+00, 3.29611589e-20],
#        [4.69105310e+00, 3.29610846e-20],
#        [4.69105942e+00, 3.29610110e-20],
#        [4.69106575e+00, 3.29609384e-20],
#        [4.69107207e+00, 3.29608677e-20],
#        [4.69107839e+00, 3.29607996e-20],
# ...

# %%
lam_vals = data[:,0]
flux_vals = data[:,1]

# %%
plt.plot(lam_vals, flux_vals)
plt.show()
